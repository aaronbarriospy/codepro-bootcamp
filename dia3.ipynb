# %%
print('Op bro, como andamos?')
# Out:
# Op bro, como andamos?

# %%
def saludar():
    print('Hola bro, que onda?')

saludar()
# Out:
# Hola bro, que onda?

# %% [markdown]
# Challenge 1
#
# Crear una funcion que imprima la variable palabra.

# %%
# DEfinir una variable llamada palabra
# Crear una funcion def imprimir_palabra
    # Imprimir la variable palabra
# Llamar a la funcion para ejecutar

palabra = 'Op'

def imprimir_palabra():
    print(palabra)

imprimir_palabra()
# Out:
# Op

# %%
# Funcion que recibe 2 numeros y suma

# Definir 2 variables con int(input()), numero1, numero2
# (Fuera de la funcion)

numero1 = int(input('Decime un numero'))
numero2 = int(input('Decime un numero'))

def suma_de_numeros():
    print(numero1 + numero2)
suma_de_numeros()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 6
#       1 # Funcion que recibe 2 numeros y suma
#       2
#       3 # Definir 2 variables con int(input()), numero1, numero2
#       4 # (Fuera de la funcion)
# ----> 6 numero1 = int(input('Decime un numero'))
#       7 numero2 = int(input('Decime un numero'))
#       9 def suma_de_numeros():
#
# ValueError: invalid literal for int() with base 10: 'HOLAS'

# %% [markdown]
# Crear una funcion que reciba dos letras (parametros) y que verifique si son iguales.
# 1-Si son iguales, imprimir las letras son iguales.
# 2-De lo contrario, imprimir las letras son diferentes.

# %%
# Crear variables
# letra1 definir variable
# letra2 definir variable
# definir la funcion verificar_letra(l1, l2):
    # if l1 == l2
        # print('Las letras son iguales')
    # else:
        # print('Las letras son diferentes')

# Llamar a la funcion con sus argumentos

letra1 = 'b'
letra2 = 'a'

def verificar_letra(l1, l2):
    if l1 == l2:
        print('Las letras son iguales')
    else:
        print('Las letras no son iguales')

        
verificar_letra(letra1, letra2)
# Out:
# Las letras son iguales

# %% [markdown]
# ## RETURN
# Devuelve el valor que ejecuto la funcion

# %%
def sumar(n1, n2):
    resultado_suma = n1 + n2
    return resultado_suma

print(type(sumar(2, 2)))

resultado = sumar(5, 8)
print(resultado)
# Out:
# <class 'int'>
# 13

# %% [markdown]
# Crear una funcion que reciba 2 parametros (una palabra y un numero), y que retorne True si el numero es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.
#
# Pista: cantidad de letras de una palabra en python

# %%
def contador(palabra, numero):
    if len(palabra) == (numero):
        print('True')
    else:
        print('False')

contador('Cuaderno', 10)


# Si tengo una lista, necesito un bucle para poder recorrer.
# Las variables pueden ser datos "?"
# Out:
# False

# %% [markdown]
# Crear funcion que revise si una palabra contiene una letra. En caso de que la contenga, retornar la letra entre corchetes.
# De lo contrario, retornar solo la letra.

# %%
### PENDIENTE ###

# %% [markdown]
# Challenge 5 🤺 - 20m
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
#
#
# Ejemplo del resultado esperado:
#
# [['c', 'i', 'e', 'l', 'o']]
#  # Al ingresar la primera palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
#  # Al ingresar la segunda palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
#  # Al ingresar la tercera palabra

# %%
palabra_ingresada = input('Ingresar tu palabra')

for palabra in range(3):
    print(f'Lista de {palabra_ingresada}')



## Solucion de Paz

palabras_ingresadas = []
for i in range(3):
    palabra = input("Ingresar palabra")
    lista_usuario = list(palabra)
    palabras_ingresadas.append(lista_usuario)
    print(palabras_ingresadas)
# Out:
# Lista de manzana
# Lista de manzana
# Lista de manzana

# %% [markdown]
# Challenge 6 🤺 - 20m
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

for i in lista:
    print(i)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %% [markdown]
# Funcion verificadora
# Crear una lista vacia de letras verificadas para las letras de la palabra luego de ser verificada
# Definir la cantidad de letras de la palabra a encontrar

# %%
letras_verificadas = []
cantidad_letras = 5
palabra_secreta = 'calor'
intentos = 0

while intentos < 6:
    print(f"te quedan {6 - intentos} intentos")
    intentos = intentos + 1
    palabra_ingresada = input("Ingrese una palabra")
    print(f"la palabra ingresada es: {palabra_ingresada}")
    
    def verificador_palabra(palabra_ingresada, palabra_secreta):
        for i in range(cantidad_letras):
            las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o False
            la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta 
            if las_palabras_son_iguales:
                letras_verificadas.append(f"[{palabra_ingresada[i]}]")
            elif la_letra_existe_en_la_palabra:
                letras_verificadas.append(f"({palabra_ingresada[i]})")
            else:
                letras_verificadas.append(palabra_ingresada[i])
        
        return letras_verificadas

verificador_palabra(palabra_ingresada,palabra_secreta)

# %%
cantidad_letras = 5
palabra_secreta = "calor"
intentos = 0

def verificador_palabra(palabra_ingresada, palabra_secreta):
    letras_verificadas = []

    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i]
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta

        if las_palabras_son_iguales:
            letras_verificadas.append(f"[{palabra_ingresada[i]}]")
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f"({palabra_ingresada[i]})")
        else:
            letras_verificadas.append(palabra_ingresada[i])

    return letras_verificadas



while intentos < 6:
    print(f"te quedan {6 - intentos} intentos")
    intentos += 1

    palabra_ingresada = input("Ingrese una palabra: ")

    resultado = verificador_palabra(palabra_ingresada, palabra_secreta)
    print(resultado)
    if palabra_ingresada == palabra_secreta:
        print('ganaste')
        break
# Out:
# te quedan 6 intentos
# ['[c]', '[a]', '(a)', '(c)', '(a)']
# te quedan 5 intentos
# ['(a)', '(l)', 's', '(a)', 's']
# te quedan 4 intentos
# ['[c]', '[a]', '[l]', '[o]', '[r]']
# ganaste
