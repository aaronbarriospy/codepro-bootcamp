# %%
# Orden de ejecucion:
fruta = "naranja"
print(fruta)
cantidad_de_frutas = 4
print(cantidad_de_frutas)
fruta = "banana"
print(fruta)

# %%
print('hola mundo')

# %%
# snake_case:
frase_famosa = "Hola mundo"

# %% [markdown]
# Tipos de datos

# %%
edad = 28 # --> Integer
altura = 1.80 # --> float
nombre = "Maggi" # --> String
feliz = True # bool

# print(edad)
# print(altura)
# print(nombre)
# print(feliz)

print(edad, altura, nombre, feliz)

# %%
nombre = "Aaron"
edad = 31
ciudad = "Asuncion"

print(nombre, edad, ciudad)

# %% [markdown]
# # Reglas para nombrar variables
# Algunas reglas y buenas practicas para nobras variables en Python:
# -Puede incluir letras, numeros y guiones bajos (_)
# -Debe empezar con una letra o guion bajo, nunca con un numero
# -Evitar usar palabras reservadas de Python (como print, def, if, etc.)
# -Usar nombres descriptivos (no pongas x, a, b si no hace falta!). En programacion un espacio vacio es un caracter, por esop al escribir variables no deben existir espacios vacios

# %% [markdown]
# # Operaciones aritmeticas con variables

# %% [markdown]
# ## Challenge 🤺 - 10m
#
# Suma: asignar dos números en dos variables diferentes `cantidad_de_manzanas` y `cantidad_de_naranjas`. Luego sumar ambas variables en `cantidad_de_frutas`. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable `frutas_vendidas`. Luego, asignar la resta entre `cantidad_de_frutas` y `frutas_vendidas` a la variable `frutas_restantes`. Imprimir la última variable.

# %%
cantidad_de_manzanas = 10
cantidad_de_naranjas = 8
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print('Total de frutas:', cantidad_de_frutas)

frutas_vendidas = 16
cantidad_de_frutas = cantidad_de_frutas - frutas_vendidas
print('Frutas restantes:', cantidad_de_frutas)
# Out:
# Total de frutas: 18
# Frutas restantes: 2

# %%
nombre = 'Aaron'
apellido = 'Barrios'

print(nombre)
print(apellido)

#Concatenar los strings
print(nombre + " " + apellido)
print('Hola mi nombre es ' + nombre + " " + "y mi apellido es " + apellido)

# Agregar el print con f
print(f'Hola mi nombre es {nombre} y mi apellido es {apellido}')
# Out:
# Aaron
# Barrios
# Aaron Barrios
# Hola mi nombre es Aaron y mi apellido es Barrios
# Hola mi nombre es Aaron y mi apellido es Barrios

# %% [markdown]
# Challenge 🤺 - 10m
# Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto.

# %%
nombre = 'Juan'
apellido = 'Rojas'

print('Ha upei? mi nombre es ' + nombre + ' y mi apellido es ' + apellido)
# Out:
# Ha upei? mi nombre es Juan y mi apellido es Rojas

# %% [markdown]
# # El input sirve para que el programa le haga una pregunta al usuario y guarde lo que responde por teclado

# %%
nombre = input('Escribe tu nombre')
print(nombre)
# Out:
# Neiber

# %%
# Solicitar al usuario un producto

producto = input('Que producto deseas')
print(producto)

# Solicitar al usuario que ingrese la cantidad

cantidad_de_producto = input('Que cantidad de producto deseas')
print(cantidad_de_producto)

print(f'El usuario quiere {cantidad_de_producto} {producto}')
# Out:
# Lamborghini
# 2
# El usuario quiere 2 Lamborghini

# %% [markdown]
# # Ver tipos de datos

# %%
edad = 19
print(type(edad))

nombre = 'Neiber'
print(type(nombre))

temperatura = 36.5
print(type(temperatura))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
edad = input('cuantos anhos tienes')
print(type(edad))

cantidad_de_anhos = int(edad)
print(type(cantidad_de_anhos))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Challenge 🤺 - 8m
# Solicitar al usuario ingresar dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.

# %%
cantidad_de_insignias = int(input('Cuantas insignias queres?'))
cantidad_de_remeras = int(input('Cuantas remeras queres?'))

print(cantidad_de_insignias + cantidad_de_remeras)
# Out:
# 20

# %% [markdown]
# # Que es un algoritmo?

# %% [markdown]
# un algoritmo es una serie de pasos o instrucciones definidos y ordenados para resolver un problema o completar una tarea especifica, muy de la manos de lo que es el pensamiento computacional.
# Los al

# %%
# Aca definimos la funcion

def preparar_sandwich():
    print('Preparar un sandwich')

    print('Ya el sandwich esta casi listo')
    
# Aqui termina la funcion

# Aqui llamamos a la funcion
preparar_sandwich()
# Out:
# Preparar un sandwich
# Ya el sandwich esta casi listo

# %% [markdown]
# Challenge 🤺 - 10m
# Crear una función de un proceso que se les ocurra que tenga varios pasos.
#
# Ejecutar la función 3 veces.

# %%
def preparar_terere():
    print('Preparando el terere')

    print('Listo el Terere Pantano patron')

preparar_terere()
preparar_terere()
preparar_terere()
# Out:
# Preparando el terere
# Listo el Terere Pantano patron
# Preparando el terere
# Listo el Terere Pantano patron
# Preparando el terere
# Listo el Terere Pantano patron

# %%
def saludar_profe():
    print('Hola profe, como te va?')

    print('Hola alumno, bien y vos?')

saludar_profe()
saludar_profe()
saludar_profe()
# Out:
# Hola profe, como te va?
# Hola alumno, bien y vos?
# Hola profe, como te va?
# Hola alumno, bien y vos?
# Hola profe, como te va?
# Hola alumno, bien y vos?

# %%
ingrediente1 = "milanesa"
ingrediente2 = "queso"

def preparar_sandwich(ingrediente1, ingrediente2):
    print(f'Preparando sandwich de {ingrediente1} con {ingrediente2}')

preparar_sandwich(ingrediente1, ingrediente2)
# Out:
# Preparando sandwich de milanesa con queso

# %% [markdown]
# Challenge 🤺 - 25m
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.

# %%
eq1 = 'Ram 32GB'
eq2 = 'Fuente 750W'
eq3 = 'Procesador Lentium 4'
eq4 = 'SSD nvme 2.0'
eq5 = 'Motherboard Carbon 5'

def armar_pc_master_race(eq1, eq2, eq3, eq4, eq5):
    print(f'Preparando PC Master Race con {eq1}, una {eq2} para aguantar los componentes, \n{eq3}, {eq4} y {eq5} para no tener cuello de botella')

armar_pc_master_race(eq1, eq2, eq3, eq4, eq5)
# Out:
# Preparando PC Master Race con Ram 32GB, una Fuente 750W para aguantar los componentes,
# Procesador Lentium 4, SSD nvme 2.0 y Motherboard Carbon 5 para no tener cuello de botella

# %% [markdown]
# Challenge 🤺 - 10m
# 🎯 Objetivo:
# Escribir una función que pregunte por las características de un producto a comprar (por ejemplo, tipo, tamaño, color) e imprima un resumen de ese producto con las características ingresadas.
#
# Además, deben trabajar con variables locales y globales.

# %%
color1 = 'negro'
color2= 'rojo'
color3= 'azul'

def remera():
    print(f'Los colores a eleccion son {color1}, {color2} y {color3}\n Cual prefiere?')
